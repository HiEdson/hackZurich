# %%
import pandas as pd
disruption = pd.read_csv('/content/drive/My Drive/Hack Zurich 2021 data/disruptions.csv')
disruption
# Out:
#         ID  ...                             Description
# 0        1  ...  Stoerung: Zwangsbremse wurde aktiviert
# 1        2  ...  Stoerung: Zwangsbremse wurde aktiviert
# 2        3  ...  Stoerung: Zwangsbremse wurde aktiviert
# 3        4  ...  Stoerung: Zwangsbremse wurde aktiviert
# 4        5  ...  Stoerung: Zwangsbremse wurde aktiviert
# ...    ...  ...                                     ...
# 2112  5639  ...            Zwangsbremse wurde aktiviert
# 2113  5640  ...            Zwangsbremse wurde aktiviert
# 2114  5641  ...            Zwangsbremse wurde aktiviert
# 2115  5642  ...            Zwangsbremse wurde aktiviert
# 2116  5643  ...            Zwangsbremse wurde aktiviert
#
# [2117 rows x 4 columns]

# %%
eventsDisrupMap = pd.read_csv('/content/drive/MyDrive/Hack Zurich 2021 data/Mapping_Events_Disruptions.csv')
eventsDisrupMap
# Out:
#     ID  ...                           Notes
# 0    1  ...                             NaN
# 1    2  ...                             NaN
# 2    3  ...                             NaN
# 3    4  ...                             NaN
# 4    5  ...                             NaN
# 5    6  ...                             NaN
# 6    7  ...                             NaN
# 7    8  ...                             NaN
# 8    9  ...                             NaN
# 9   10  ...                             NaN
# 10  11  ...                             NaN
# 11  12  ...     [dm]: decimeters (1dm=10cm)
# 12  13  ...                             NaN
# 13  14  ...                             NaN
# 14  15  ...                             NaN
# 15  16  ...                             NaN
# 16  17  ...                             NaN
# 17  18  ...                             NaN
# 18  19  ...                             NaN
# 19  20  ...                             NaN
# ...

# %%
import pandas as pd
rssi = pd.read_csv('/content/drive/MyDrive/Hack Zurich 2021 data/rssi.csv')

# %%
events = pd.read_csv('/content/drive/MyDrive/Hack Zurich 2021 data/events.csv')

# %%
velocities = pd.read_csv('/content/drive/MyDrive/Hack Zurich 2021 data/velocities.csv')

# %%
rssi
# Out:
#                 ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 0                1  2021-01-09 00:00:01  ...      1553797      1549606
# 1                2  2021-01-09 00:00:02  ...      1553802      1549611
# 2                3  2021-01-09 00:00:03  ...      1553807      1549616
# 3                4  2021-01-09 00:00:04  ...      1553812      1549621
# 4                5  2021-01-09 00:00:05  ...      1553816      1549625
# ...            ...                  ...  ...          ...          ...
# 30975724  31017016  2021-06-25 07:50:59  ...        78912        78911
# 30975725  31017017  2021-06-25 07:51:00  ...        78912        78911
# 30975726  31017018  2021-06-25 07:51:01  ...        78912        78911
# 30975727  31017019  2021-06-25 07:51:02  ...        78912        78911
# 30975728  31017020  2021-06-25 07:51:03  ...        78912        78911
#
# [30975729 rows x 13 columns]

# %%
events
# Out:
#           ID  ...                                        Description
# 0        352  ...                   Zwangsbremsung | Initialisierung
# 1        353  ...  Zugdaten bestaetigt: | Zuglaenge [dm]: 410 | B...
# 2        354  ...  Zugdaten bestaetigt: | Zuglaenge [dm]: 410 | B...
# 3        355  ...                   Zwangsbremsung | Initialisierung
# 4        356  ...                   Zwangsbremsung | Initialisierung
# ...      ...  ...                                                ...
# 32967  33627  ...                         Rueckstellung Zwangsbremse
# 32968  33628  ...                Zwangsbremsung | Manoever nicht ein
# 32969  33629  ...                         Rueckstellung Zwangsbremse
# 32970  33630  ...                      Manoever        eingeschaltet
# 32971  33631  ...              Ueberbrueckung: 0 | Fahrzeug gefuehrt
#
# [32972 rows x 4 columns]

# %%
velocities
# Out:
#                 ID             DateTime  ...  AllowedVelocity  EmergencyStopLimit
# 0         19642270  2020-01-22 00:00:01  ...                0                   0
# 1         19642271  2020-01-22 00:00:02  ...                0                   0
# 2         19642272  2020-01-22 00:00:03  ...                0                   0
# 3         19642273  2020-01-22 00:00:04  ...                0                   0
# 4         19642274  2020-01-22 00:00:05  ...                0                   0
# ...            ...                  ...  ...              ...                 ...
# 29772320  19642246  2021-06-25 07:50:59  ...                0                   0
# 29772321  19642247  2021-06-25 07:51:00  ...                0                   0
# 29772322  19642248  2021-06-25 07:51:01  ...                0                   0
# 29772323  19642249  2021-06-25 07:51:02  ...                0                   0
# ...

# %%
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

# %%
sums = eventsDisrupMap.groupby(['DescriptionEnglish'])['EventDisruptionCode'].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
eventsDisrupMap['DescriptionEnglish'].value_counts()
# Out:
# Date/time changed                                                                                                                      2
# Train data changed | Train length [dm]: {xxx} | Brake value [%]: {xxx} | VMaxFzg [km/h]: {xxx}                                         2
# Signal {XX_YY} bypassed                                                                                                                2
# Train data confirmed | Train length [dm]: {xxx} | Brake value [%]: {xxx} | VMaxFzg [km/h]: {xxx}                                       2
# Disruption of position ZSI0 | Cause: Calibration error                                                                                 2
# Disruption of position ZSI0 | Cause: Initialisation                                                                                    2
# Emergency brake reset                                                                                                                  2
# ...

# %%
rssipart = rssi.iloc[:1000,:]

# %%
rssipart
# Out:
#        ID             DateTime  AreaNumber  ...  A2_RSSI  A2_TotalTel  A2_ValidTel
# 0       1  2021-01-09 00:00:01          33  ...     2.09      1553797      1549606
# 1       2  2021-01-09 00:00:02          33  ...     1.99      1553802      1549611
# 2       3  2021-01-09 00:00:03          33  ...     2.05      1553807      1549616
# 3       4  2021-01-09 00:00:04          33  ...     2.06      1553812      1549621
# 4       5  2021-01-09 00:00:05          33  ...     1.75      1553816      1549625
# ..    ...                  ...         ...  ...      ...          ...          ...
# 995   996  2021-01-09 00:16:36          40  ...     2.57      1558453      1554259
# 996   997  2021-01-09 00:16:37          40  ...     2.53      1558458      1554264
# 997   998  2021-01-09 00:16:38          40  ...     2.43      1558462      1554268
# 998   999  2021-01-09 00:16:39          40  ...     2.26      1558467      1554273
# ...

# %%
div = rssipart.apply(lambda x: x['A1_TotalTel'] / x['A1_ValidTel'], axis = 1)

# %%
div
# Out:
# 0      1.013572
# 1      1.013572
# 2      1.013572
# 3      1.013572
# 4      1.013572
#          ...
# 995    1.013536
# 996    1.013536
# 997    1.013536
# 998    1.013536
# 999    1.013536
# Length: 1000, dtype: float64

# %%
sub = [div[i-1] - div[i] for i in range(1, len(div))]

# %%
sub
# Out:
# [3.919616808900628e-08,
#  3.919594182555386e-08,
#  3.9195715340056836e-08,
#  3.135640924689653e-08,
#  3.91953078882068e-08,
#  3.919508162475438e-08,
#  3.919485491721275e-08,
#  3.919462865376033e-08,
#  3.9194402390307914e-08,
#  3.919417590481089e-08,
#  3.135517778751762e-08,
#  3.919376845296085e-08,
#  3.919354196746383e-08,
#  3.919331570401141e-08,
#  3.919308921851439e-08,
#  3.919286295506197e-08,
#  3.9192636469564945e-08,
#  3.13539461060941e-08,
#  3.919222923975951e-08,
#  3.9192002532217884e-08,
#  3.9191776268765466e-08,
#  3.919155000531305e-08,
#  3.919132374186063e-08,
#  3.9191097034319e-08,
#  3.135271486875979e-08,
#  3.919068980451357e-08,
#  3.919046354106115e-08,
#  3.9190237055564126e-08,
#  3.91900105700671e-08,
#  3.918978452865929e-08,
#  3.9189558043162265e-08,
#  3.1351483409380876e-08,
#  3.918915059131223e-08,
#  3.1351157447900846e-08,
#  3.9188743361506795e-08,
#  3.918851687600977e-08,
#  3.13506505200678e-08,
#  3.9188109424159734e-08,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sub)

# %%
rssi.head(100).to_csv("/content/drive/MyDrive/Hack Zurich 2021 data/testRssi.csv")

# %%
rssipart['DateTime'][4]
# Out:
# '2021-01-09 00:00:05'

# %%
index = -1

for i in range(0, disruption.shape[0]) :
  print(disruption['DateTime'][i])
  if disruption['DateTime'][i] == '2021-01-09 04:54:39':
    index = i

index
# Out:
# 2020-02-08 04:37:25
# 2020-02-08 04:41:39
# 2020-02-08 08:06:31
# 2020-02-08 16:18:53
# 2020-02-10 03:06:12
# 2020-02-10 03:08:53
# 2020-02-10 16:52:17
# 2020-02-11 04:14:08
# 2020-02-11 04:18:15
# 2020-02-11 05:41:25
# 2020-02-11 12:58:04
# 2020-02-11 15:50:13
# 2020-02-11 19:36:38
# 2020-02-12 03:59:49
# 2020-02-12 04:18:35
# 2020-02-12 06:35:41
# 2020-02-12 16:34:30
# 2020-02-13 03:51:47
# 2020-02-13 03:59:12
# 2020-02-13 16:56:00
# 2020-02-14 04:01:27
# 2020-02-14 04:05:03
# 2020-02-14 05:45:49
# 2020-02-14 06:12:39
# 2020-02-14 15:51:08
# 2020-02-14 15:51:39
# 2020-02-14 19:37:04
# 2020-02-15 04:17:45
# 2020-02-15 04:20:30
# 2020-02-17 02:43:03
# 2020-02-17 02:53:57
# 2020-02-17 16:35:37
# 2020-02-17 17:46:22
# 2020-02-18 04:14:26
# 2020-02-18 04:17:14
# 2020-02-18 06:50:58
# 2020-02-18 16:34:46
# 2020-02-19 04:15:37
# 2020-02-19 04:18:33
# 2020-02-19 13:37:37
# 2020-02-19 16:21:02
# 2020-02-19 16:21:21
# 2020-02-19 17:12:45
# 2020-02-19 17:12:45
# 2020-02-20 03:29:58
# ...

# %%
rssipart2 = rssi.iloc[10000:30000,:]

# %%
index = -1

for i in range(10000, rssipart2.shape[0]) :
  # print(rssipart2['DateTime'][i])
  if rssipart2['DateTime'][i] == '2021-01-09 04:54:39':
    index = i

index
# Out:
# 17678

# %%
rssipart2['DateTime'][17678]
# Out:
# '2021-01-09 04:54:39'

# %%
rssipart2.loc[17678]
# Out:
# ID                              17679
# DateTime          2021-01-09 04:54:39
# AreaNumber                         40
# Track                               2
# Position                       420051
# PositionNoLeap                 426801
# Latitude                      47.2414
# Longitude                     8.18919
# A1_TotalTel                   1835724
# A1_ValidTel                   1812226
# A2_RSSI                          2.19
# A2_TotalTel                   1634768
# A2_ValidTel                   1630574
# Name: 17678, dtype: object

# %%
disruption.loc[1370]
# Out:
# ID                                        4489
# DateTime                   2021-01-09 07:21:55
# DisruptionCode                       960862267
# Description       Zwangsbremse wurde aktiviert
# Name: 1370, dtype: object

# %%
index = -1

for i in range(0, eventsDisrupMap.shape[0]) :
  # print(rssipart2['DateTime'][i])
  if eventsDisrupMap['EventDisruptionCode'][i] == '960862267':
    index = i

index
# Out:
# -1

# %%
rssipart3 = rssi.iloc[0:20000,:]

# %%
snr = rssipart3.apply(lambda x: x['A1_ValidTel'] / (x['A1_TotalTel'] -  x['A1_ValidTel']), axis = 1)

# %%
snr
# Out:
# 0        73.682712
# 1        73.682925
# 2        73.683138
# 3        73.683350
# 4        73.683521
#            ...
# 19995    77.573453
# 19996    77.573666
# 19997    77.573836
# 19998    77.574049
# 19999    77.574262
# Length: 20000, dtype: float64

# %%
snr = [x/20 for x in snr]

# %%
VR = [pow(10,x) for x in snr]

# %%
VR
# Out:
# [1.5282935487881082,
#  1.5282954209302275,
#  1.52829729307464,
#  1.5282991652213458,
#  1.5283006629403617,
#  1.5283025350911956,
#  1.5283044072443228,
#  1.5283062793997435,
#  1.5283081515574575,
#  1.5283100237174647,
#  1.5283118958797657,
#  1.5283133936112574,
#  1.5283152657776864,
#  1.5283171379464084,
#  1.5283190101174242,
#  1.5283208822907333,
#  1.5283227544663356,
#  1.5283246266442312,
#  1.5283261243881991,
#  1.528327996570223,
#  1.5283298687545404,
#  1.5283317409411512,
#  1.5283336131300551,
#  1.5283354853212527,
#  1.5283373575147436,
#  1.5283388552711876,
#  1.5283407274688068,
#  1.5283425996687192,
#  1.5283444718709251,
#  1.5283463440754246,
#  1.5283482162822173,
#  1.5283500884913035,
#  1.528351586260224,
#  1.5283534584734382,
#  1.5283549562456609,
#  1.5283568284630036,
#  1.5283587006826396,
#  1.5283601984599997,
#  1.528362070683764,
#  1.5283639429098217,
#  1.5283658151381727,
#  1.5283676873688175,
#  1.5283695596017555,
# ...

# %%
plt.plot(VR)

# %%
rssi.head()
# Out:
#    ID             DateTime  AreaNumber  ...  A2_RSSI  A2_TotalTel  A2_ValidTel
# 0   1  2021-01-09 00:00:01          33  ...     2.09      1553797      1549606
# 1   2  2021-01-09 00:00:02          33  ...     1.99      1553802      1549611
# 2   3  2021-01-09 00:00:03          33  ...     2.05      1553807      1549616
# 3   4  2021-01-09 00:00:04          33  ...     2.06      1553812      1549621
# 4   5  2021-01-09 00:00:05          33  ...     1.75      1553816      1549625
#
# [5 rows x 13 columns]

# %%
disruption.head()
# Out:
#    ID  ...                             Description
# 0   1  ...  Stoerung: Zwangsbremse wurde aktiviert
# 1   2  ...  Stoerung: Zwangsbremse wurde aktiviert
# 2   3  ...  Stoerung: Zwangsbremse wurde aktiviert
# 3   4  ...  Stoerung: Zwangsbremse wurde aktiviert
# 4   5  ...  Stoerung: Zwangsbremse wurde aktiviert
#
# [5 rows x 4 columns]

# %%
import seaborn as sns
bplot=sns.boxplot(x=rssi['A1_TotalTel'])

# %%
bplot=sns.boxplot(x=rssi['A1_ValidTel'])

# %%
n = rssi.shape[0]

# %%
q1 = (n + 1) /4
q1
# Out:
# 7743932.5

# %%
q3 = 3 * q1
q3
# Out:
# 23231797.5

# %%
leftquartile =  rssi.loc[:q1,:]
leftquartile
# Out:
#               ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 0              1  2021-01-09 00:00:01  ...      1553797      1549606
# 1              2  2021-01-09 00:00:02  ...      1553802      1549611
# 2              3  2021-01-09 00:00:03  ...      1553807      1549616
# 3              4  2021-01-09 00:00:04  ...      1553812      1549621
# 4              5  2021-01-09 00:00:05  ...      1553816      1549625
# ...          ...                  ...  ...          ...          ...
# 7743928  7762423  2020-05-31 00:19:18  ...       308391       308010
# 7743929  7762424  2020-05-31 00:19:19  ...       308395       308014
# 7743930  7762425  2020-05-31 00:19:20  ...       308400       308019
# 7743931  7762426  2020-05-31 00:19:21  ...       308405       308024
# 7743932  7762427  2020-05-31 00:19:22  ...       308409       308028
#
# [7743933 rows x 13 columns]

# %%
rightquartile = rssi.loc[q3:,:]
rightquartile
# Out:
#                 ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 23231798  23271739  2021-02-15 15:18:39  ...       145217       144854
# 23231799  23271740  2021-02-15 15:18:40  ...       145222       144859
# 23231800  23271741  2021-02-15 15:18:41  ...       145227       144864
# 23231801  23271742  2021-02-15 15:18:42  ...       145232       144869
# 23231802  23271743  2021-02-15 15:18:43  ...       145237       144874
# ...            ...                  ...  ...          ...          ...
# 30975724  31017016  2021-06-25 07:50:59  ...        78912        78911
# 30975725  31017017  2021-06-25 07:51:00  ...        78912        78911
# 30975726  31017018  2021-06-25 07:51:01  ...        78912        78911
# 30975727  31017019  2021-06-25 07:51:02  ...        78912        78911
# 30975728  31017020  2021-06-25 07:51:03  ...        78912        78911
#
# [7743931 rows x 13 columns]

# %%
bplot=sns.boxplot(x=leftquartile['A1_ValidTel'])

# %%
bplot=sns.boxplot(x=rightquartile['A1_ValidTel'])

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 15487865.0

# %%
si = q1 - 1.5*iqr

# %%
si
# Out:
# -15487865.0

# %%
ei = q3 + 1.5*iqr

# %%
ei
# Out:
# 46463595.0

# %%
n = leftquartile.shape[0]
leftquartileQ1 = (n+1)/4
leftquartileQ3 = 3 * leftquartileQ1
iqr = leftquartileQ3 - leftquartileQ1

# %%
subleft = rssi.loc[:leftquartileQ1,:]
bplot=sns.boxplot(x=subleft['A1_ValidTel'])

# %%
subright = rssi.loc[leftquartileQ3:q1,:]
bplot=sns.boxplot(x=subright['A1_ValidTel'])

# %%
subright
# Out:
#                 ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 5807951    5820029  2020-04-14 17:04:25  ...       204443       202966
# 5807952    5820030  2020-04-14 17:04:26  ...       204447       202970
# 5807953    5820031  2020-04-14 17:04:27  ...       204452       202975
# 5807954    5820032  2020-04-14 17:04:28  ...       204456       202979
# 5807955    5820033  2020-04-14 17:04:29  ...       204460       202983
# ...            ...                  ...  ...          ...          ...
# 30975724  31017016  2021-06-25 07:50:59  ...        78912        78911
# 30975725  31017017  2021-06-25 07:51:00  ...        78912        78911
# 30975726  31017018  2021-06-25 07:51:01  ...        78912        78911
# 30975727  31017019  2021-06-25 07:51:02  ...        78912        78911
# 30975728  31017020  2021-06-25 07:51:03  ...        78912        78911
#
# [25167778 rows x 13 columns]

# %%
n = rightquartile.shape[0]
rightquartileQ1 = (n+1)/4
rightquartileQ3 = 3 * rightquartileQ1
iqr = rightquartileQ3 - rightquartileQ1

# %%
subleftright = rssi.loc[q3:rightquartileQ1,:]
bplot=sns.boxplot(x=subleftright['A1_ValidTel'])

# %%
subrightright = rssi.loc[rightquartileQ3:,:]
bplot=sns.boxplot(x=subrightright['A1_ValidTel'])

# %%
n = subleft.shape[0]
Q1 = (n+1)/4
Q3 = 3 * Q1

# %%
#left
subleft2 = rssi.loc[:Q1,:]
bplot=sns.boxplot(x=subleft2['A1_ValidTel'])

# %%
#right
subleft3 = rssi.loc[Q3:leftquartileQ1,:]
bplot=sns.boxplot(x=subleft3['A1_ValidTel'])

# %%
n = subrightright.shape[0]
rightq1 = (n+1)/4
rightq3 = 3 * rightquartileQ1

# %%
#left
subright2 = rssi.loc[rightquartileQ3:rightq1,:]
bplot=sns.boxplot(x=subright2['A1_ValidTel'])

# %%
#right
subright3 = rssi.loc[rightq3:,:]
bplot=sns.boxplot(x=subright3['A1_ValidTel'])

# %%
subright3
# Out:
#                 ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 5807949    5820027  2020-04-14 17:04:23  ...       204435       202958
# 5807950    5820028  2020-04-14 17:04:24  ...       204439       202962
# 5807951    5820029  2020-04-14 17:04:25  ...       204443       202966
# 5807952    5820030  2020-04-14 17:04:26  ...       204447       202970
# 5807953    5820031  2020-04-14 17:04:27  ...       204452       202975
# ...            ...                  ...  ...          ...          ...
# 30975724  31017016  2021-06-25 07:50:59  ...        78912        78911
# 30975725  31017017  2021-06-25 07:51:00  ...        78912        78911
# 30975726  31017018  2021-06-25 07:51:01  ...        78912        78911
# 30975727  31017019  2021-06-25 07:51:02  ...        78912        78911
# 30975728  31017020  2021-06-25 07:51:03  ...        78912        78911
#
# [25167780 rows x 13 columns]

# %%
subleft2
# Out:
#             ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 0            1  2021-01-09 00:00:01  ...      1553797      1549606
# 1            2  2021-01-09 00:00:02  ...      1553802      1549611
# 2            3  2021-01-09 00:00:03  ...      1553807      1549616
# 3            4  2021-01-09 00:00:04  ...      1553812      1549621
# 4            5  2021-01-09 00:00:05  ...      1553816      1549625
# ...        ...                  ...  ...          ...          ...
# 483992  489585  2020-02-01 21:24:49  ...       291071       291040
# 483993  489586  2020-02-01 21:24:50  ...       291076       291045
# 483994  489587  2020-02-01 21:24:51  ...       291080       291049
# 483995  489588  2020-02-01 21:24:52  ...       291084       291053
# 483996  489589  2020-02-01 21:24:53  ...       291088       291057
#
# [483997 rows x 13 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
  
# A custom function to calculate
# probability distribution function
def pdf(x):
    mean = np.mean(x)
    std = np.std(x)
    y_out = 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2))
    return y_out
  
# To generate an array of x-values
x = np.arange(-2, 2, 0.1)
  
# To generate an array of 
# y-values using corresponding x-values
y = pdf(x)
  
# To fill in values under the bell-curve
x_fill = np.arange(-2, 2, 0.1)
y_fill = pdf(x_fill)
  
# Plotting the bell-shaped curve
plt.style.use('seaborn')
plt.figure(figsize = (6, 6))
plt.plot(x, y, color = 'black',
         linestyle = 'dashed')
  
plt.scatter(x, y, marker = 'o',
            s = 25, color = 'red')
  
plt.fill_between(x_fill, y_fill, 0,
                 alpha = 0.2, color = 'blue')
plt.show()

# %%
count = 0
for  i in range(len(rssi)):
  if rssi['A2_RSSI'][i] < 1.2:
    count += 1

# %%
count
# Out:
# 3110708

# %%
rssi['A2_RSSI'] < 1.2
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 30975724     True
# 30975725     True
# 30975726     True
# 30975727     True
# 30975728     True
# Name: A2_RSSI, Length: 30975729, dtype: bool

# %%
rssi.tail()
# Out:
#                 ID             DateTime  ...  A2_TotalTel  A2_ValidTel
# 30975724  31017016  2021-06-25 07:50:59  ...        78912        78911
# 30975725  31017017  2021-06-25 07:51:00  ...        78912        78911
# 30975726  31017018  2021-06-25 07:51:01  ...        78912        78911
# 30975727  31017019  2021-06-25 07:51:02  ...        78912        78911
# 30975728  31017020  2021-06-25 07:51:03  ...        78912        78911
#
# [5 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(rssi['A2_RSSI'])

# %%
import matplotlib.pyplot as plt
plt.plot(rssi['A2_RSSI']<1.2)

# %%
filter = rssi.apply(lambda x: x['A2_RSSI'] < 1.2, axis = 1)

# %%
noise=rssi['A1_TotalTel']-rssi['A1_ValidTel']
noise.value_counts()
# Out:
# 0         2344720
# 253        244145
# 1          212700
# 1225       209661
# 252        201136
#            ...
# 72620           1
# 39836           1
# 154565          1
# 88997           1
# 73524           1
# Length: 129718, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(noise)

# %%
noise.head()
# Out:
# 0    23496
# 1    23496
# 2    23496
# 3    23496
# 4    23496
# dtype: int64

# %%
part = noise.loc[17000000:24300000]

# %%
plt.plot(part)

# %%
part2 = noise.loc[23600000:24200000]

# %%
plt.plot(part2)

# %%
noise.mean()
# Out:
# 4750.158110370865

# %%
rssi['noise'] = noise

# %%
rssi.head()
# Out:
#    ID             DateTime  AreaNumber  ...  A2_TotalTel  A2_ValidTel  noise
# 0   1  2021-01-09 00:00:01          33  ...      1553797      1549606  23496
# 1   2  2021-01-09 00:00:02          33  ...      1553802      1549611  23496
# 2   3  2021-01-09 00:00:03          33  ...      1553807      1549616  23496
# 3   4  2021-01-09 00:00:04          33  ...      1553812      1549621  23496
# 4   5  2021-01-09 00:00:05          33  ...      1553816      1549625  23496
#
# [5 rows x 14 columns]

# %%
rssi['DateTime'][0]
# Out:
# '2021-01-09 00:00:01'

# %%
rssi['DateTime'][24100000]
# Out:
# '2021-02-25 16:29:35'

# %%
index = -1

for i in range(0, disruption.shape[0]) :
  print(disruption['DateTime'][i])
  if disruption['DateTime'][i] == '2021-02-25 16:29:35':
    index = i

index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-076485e2ee0d> in <module>()
#       1 index = -1
#       2
# ----> 3 for i in range(0, disruption.shape[0]) :
#       4   print(disruption['DateTime'][i])
#       5   if disruption['DateTime'][i] == '2021-02-25 16:29:35':
#
# NameError: name 'disruption' is not defined

# %%
index = -1

for i in range(10000, rssi.shape[0]) :
  # print(rssipart2['DateTime'][i])
  if rssi['DateTime'][i] == '2021-02-25 16:35:57':
    index = i

index
# Out:
# 24100382

# %%
rssi['A2_RSSI']>2 and (rssi['A1_ValidTel'] / rssi['noise'])

# %%
snr = rssi['A1_ValidTel']/rssi['noise']

# %%
snr[1000000]
# Out:
# 1142.0330578512396

# %%
plt.plot(snr)

# %%
count = 0
for i in range(0, rssi.shape[0]) :
  if rssi['A2_RSSI'][i]>2 and snr[i] > 100:
    # print(rssi['A1_ValidTel'][i]/rssi['noise'][i])
    count += 1

# %%
count
# Out:
# 23245155

# %%
snr.value_counts().plot(kind='barh', figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-55a5f75467f7> in <module>()
# ----> 1 snr.value_counts().plot(kind='barh', figsize=(10,5))
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
snr.mean()
# Out:
# inf

# %%
snr.head()
# Out:
# 0    73.682712
# 1    73.682925
# 2    73.683138
# 3    73.683350
# 4    73.683521
# dtype: float64

# %%
# Out:
# inf

# %%
rssiBad = rssi[(rssi['A2_RSSI'] <= 2) & (rssi['snr'] <= 100)]

# %%
rssi['snr'] = snr

# %%
rssiBad
# Out:
#                 ID             DateTime  ...  noise        snr
# 1                2  2021-01-09 00:00:02  ...  23496  73.682925
# 4                5  2021-01-09 00:00:05  ...  23496  73.683521
# 5                6  2021-01-09 00:00:06  ...  23496  73.683733
# 6                7  2021-01-09 00:00:07  ...  23496  73.683946
# 7                8  2021-01-09 00:00:08  ...  23496  73.684159
# ...            ...                  ...  ...    ...        ...
# 30849924  30891213  2021-06-23 10:04:34  ...     20  47.050000
# 30849925  30891214  2021-06-23 10:04:35  ...     20  47.300000
# 30849926  30891215  2021-06-23 10:04:36  ...     20  47.500000
# 30849927  30891216  2021-06-23 10:04:37  ...     20  47.750000
# 30849928  30891217  2021-06-23 10:04:38  ...     20  48.000000
#
# [2016818 rows x 15 columns]

# %%
disruption.head()
# Out:
#    ID  ...                             Description
# 0   1  ...  Stoerung: Zwangsbremse wurde aktiviert
# 1   2  ...  Stoerung: Zwangsbremse wurde aktiviert
# 2   3  ...  Stoerung: Zwangsbremse wurde aktiviert
# 3   4  ...  Stoerung: Zwangsbremse wurde aktiviert
# 4   5  ...  Stoerung: Zwangsbremse wurde aktiviert
#
# [5 rows x 4 columns]

# %%
for i in range(0, disruption.shape[0]):
  k = i
  date = disruption['DateTime'][i]
  for j in range(0, rssiBad.shape[0]):
    if date == rssiBad['DateTime'][j]:
      k = j
      print(k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-394729fef732> in <module>()
#       3   date = disruption['DateTime'][i]
#       4   for j in range(0, rssiBad.shape[0]):
# ----> 5     if date.str == rssiBad['DateTime'][j].str:
#       6       k = j
#       7       print(k)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
rssiBad.to_csv("/content/drive/MyDrive/Hack Zurich 2021 data/rssiBad.csv")

# %%
import matplotlib.pyplot as plt

plt.plot(rssi['A2_RSSI'])
